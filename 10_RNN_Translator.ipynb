# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/castorgit/DL-course/blob/main/10_RNN_Translator.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !wget http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# !unzip -q spa-eng.zip
# Out:
# --2025-01-13 18:29:14--  http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.200.91, 142.250.201.91, 216.58.215.155, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.200.91|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2638744 (2.5M) [application/zip]
# Saving to: ‘spa-eng.zip’
#
# spa-eng.zip         100%[===================>]   2.52M  --.-KB/s    in 0.08s
#
# 2025-01-13 18:29:15 (32.5 MB/s) - ‘spa-eng.zip’ saved [2638744/2638744]
#
# replace spa-eng/_about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
text_file = "spa-eng/spa.txt"
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    english, spanish = line.split("\t")
    spanish = "[start] " + spanish + " [end]"
    text_pairs.append((english, spanish))

# %%
import random
print(random.choice(text_pairs))
# Out:
# ('Weeds sprang up in the garden.', '[start] Las malas hierbas aparecieron súbitamente en el jardín. [end]')

# %%
import random
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples:num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples:]

# %%
import tensorflow as tf
import string
import re
from tensorflow import keras
from tensorflow.keras import layers

strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(
        lowercase, f"[{re.escape(strip_chars)}]", "")

vocab_size = 15000
sequence_length = 20

source_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
target_vectorization = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_english_texts = [pair[0] for pair in train_pairs]
train_spanish_texts = [pair[1] for pair in train_pairs]
source_vectorization.adapt(train_english_texts)
target_vectorization.adapt(train_spanish_texts)

# %%
batch_size = 64

def format_dataset(eng, spa):
    eng = source_vectorization(eng)
    spa = target_vectorization(spa)
    return ({
        "english": eng,
        "spanish": spa[:, :-1],
    }, spa[:, 1:])

def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset, num_parallel_calls=4)
    return dataset.shuffle(2048).prefetch(16).cache()

train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %%
for inputs, targets in train_ds.take(1):
    print(f"inputs['english'].shape: {inputs['english'].shape}")
    print(f"inputs['spanish'].shape: {inputs['spanish'].shape}")
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs['english'].shape: (64, 20)
# inputs['spanish'].shape: (64, 20)
# targets.shape: (64, 20)
# 2025-01-13 18:32:21.938266: W tensorflow/core/kernels/data/cache_dataset_ops.cc:913] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2025-01-13 18:32:21.939467: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
from tensorflow import keras
from tensorflow.keras import layers

embed_dim = 256
latent_dim = 1024

source = keras.Input(shape=(None,), dtype="int64", name="english")
x = layers.Embedding(vocab_size, embed_dim, mask_zero=True)(source)
encoded_source = layers.Bidirectional(
    layers.GRU(latent_dim), merge_mode="sum")(x)

# %%
past_target = keras.Input(shape=(None,), dtype="int64", name="spanish")
x = layers.Embedding(vocab_size, embed_dim, mask_zero=True)(past_target)
decoder_gru = layers.GRU(latent_dim, return_sequences=True)
x = decoder_gru(x, initial_state=encoded_source)
x = layers.Dropout(0.5)(x)
target_next_step = layers.Dense(vocab_size, activation="softmax")(x)
seq2seq_rnn = keras.Model([source, past_target], target_next_step)

# %%
seq2seq_rnn.compile(
    optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
seq2seq_rnn.fit(train_ds, epochs=15, validation_data=val_ds)
# Out:
# Epoch 1/15
# /home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['english', 'spanish']. Received: the structure of inputs={'english': '*', 'spanish': '*'}
#   warnings.warn(
# 2025-01-13 18:33:32.819635: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2025-01-13 18:33:44.525744: W external/local_tsl/tsl/framework/bfc_allocator.cc:482] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.66GiB (rounded to 3932160000)requested by op StatefulPartitionedCall/gradient_tape/functional_1/dense_1/MatMul/MatMul_1
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-01-13 18:33:44.525876: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2025-01-13 18:33:44.525898: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 47, Chunks in use: 47. 11.8KiB allocated for chunks. 11.8KiB in use in bin. 543B client-requested in use in bin.
# 2025-01-13 18:33:44.525910: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-01-13 18:33:44.525919: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 3, Chunks in use: 3. 3.2KiB allocated for chunks. 3.2KiB in use in bin. 3.0KiB client-requested in use in bin.
# 2025-01-13 18:33:44.525927: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 1, Chunks in use: 0. 2.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-01-13 18:33:44.525935: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 2, Chunks in use: 0. 11.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-01-13 18:33:44.525944: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 2, Chunks in use: 2. 20.0KiB allocated for chunks. 20.0KiB in use in bin. 20.0KiB client-requested in use in bin.
# 2025-01-13 18:33:44.525954: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 8, Chunks in use: 7. 198.0KiB allocated for chunks. 168.0KiB in use in bin. 168.0KiB client-requested in use in bin.
# 2025-01-13 18:33:44.525963: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 4, Chunks in use: 4. 235.0KiB allocated for chunks. 235.0KiB in use in bin. 234.4KiB client-requested in use in bin.
# 2025-01-13 18:33:44.525972: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 2, Chunks in use: 2. 211.5KiB allocated for chunks. 211.5KiB in use in bin. 211.2KiB client-requested in use in bin.
# 2025-01-13 18:33:44.525979: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-01-13 18:33:44.525988: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 6, Chunks in use: 6. 1.69MiB allocated for chunks. 1.69MiB in use in bin. 1.50MiB client-requested in use in bin.
# 2025-01-13 18:33:44.525995: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 1, Chunks in use: 0. 965.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-01-13 18:33:44.526004: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 5, Chunks in use: 4. 6.96MiB allocated for chunks. 5.21MiB in use in bin. 5.00MiB client-requested in use in bin.
# 2025-01-13 18:33:44.526013: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 5, Chunks in use: 5. 15.00MiB allocated for chunks. 15.00MiB in use in bin. 15.00MiB client-requested in use in bin.
# 2025-01-13 18:33:44.526022: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 9, Chunks in use: 8. 44.98MiB allocated for chunks. 40.98MiB in use in bin. 36.00MiB client-requested in use in bin.
# 2025-01-13 18:33:44.526032: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks:
: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,1024,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2025-01-13 18:33:44.527116: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,1024,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{function_node __inference_one_step_on_data_3978}}{{node gradient_tape/functional_1/dense_1/MatMul/MatMul_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 2025-01-13 18:33:44.527142: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12308121785396998578
# 2025-01-13 18:33:44.527162: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9902992123131154703
# 2025-01-13 18:33:44.527179: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 4297998565669733373
# 2025-01-13 18:33:44.527197: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10170681442222027897
# 2025-01-13 18:33:44.527208: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 18280166501697000673
# 2025-01-13 18:33:44.527221: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 9954474813983409955
# 2025-01-13 18:33:44.527233: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 6692779912332175815
# 2025-01-13 18:33:44.527243: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 3808175360263289845
# 2025-01-13 18:33:44.527262: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 12484262299559084664
# 2025-01-13 18:33:44.527272: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 15703434314874279194
# 2025-01-13 18:33:44.527282: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 14249711688525170274
# 2025-01-13 18:33:44.527295: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 1265539000852293294
# 2025-01-13 18:33:44.527308: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 13252286413502811136
# 2025-01-13 18:33:44.527384: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 8340609829956976608
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[16], line 5
#       1 seq2seq_rnn.compile(
#       2     optimizer="rmsprop",
#       3     loss="sparse_categorical_crossentropy",
#       4     metrics=["accuracy"])
# ----> 5 seq2seq_rnn.fit(train_ds, epochs=15, validation_data=val_ds)
#
# File ~/DL-Keras/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/DL-Keras/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node gradient_tape/functional_1/dense_1/MatMul/MatMul_1 defined at (most recent call last):
#   File "/usr/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#
#   File "/usr/lib/python3.12/runpy.py", line 88, in _run_code
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/ipykernel_22811/3093225856.py", line 5, in <module>
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 320, in fit
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 108, in one_step_on_data
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 70, in train_step
#
# Detected at node gradient_tape/functional_1/dense_1/MatMul/MatMul_1 defined at (most recent call last):
#   File "/usr/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#
#   File "/usr/lib/python3.12/runpy.py", line 88, in _run_code
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/ipykernel_22811/3093225856.py", line 5, in <module>
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 320, in fit
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 108, in one_step_on_data
#
#   File "/home/jau/DL-Keras/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 70, in train_step
#
# 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[64,1024,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/functional_1/dense_1/MatMul/MatMul_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[StatefulPartitionedCall/rmsprop/cond_1/then/_53/rmsprop/cond_1/ones_1/_58]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[64,1024,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/functional_1/dense_1/MatMul/MatMul_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_one_step_on_iterator_4049]

# %%
import numpy as np
spa_vocab = target_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20

def decode_sequence(input_sentence):
    tokenized_input_sentence = source_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = target_vectorization([decoded_sentence])
        next_token_predictions = seq2seq_rnn.predict(
            [tokenized_input_sentence, tokenized_target_sentence])
        sampled_token_index = np.argmax(next_token_predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(20):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print(input_sentence)
    print(decode_sequence(input_sentence))
