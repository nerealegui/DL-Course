# %% [markdown]
# # Data augmentation examples with Keras
#
# **Description:** ImageDataGenerator use examples <br>
#               we apply several augmentation strategies<br>
# **Dataset:** Can be run on any .jpeg image <br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.src.legacy.preprocessing.image import ImageDataGenerator

# %%
# function to plot 9 thumbnails
def plot_thumbnails(iterator_images):
    fig, axs = plt.subplots(3,3, figsize=(9,9))
    for i in range(9):
       plt.subplot(330 + 1 + i)
       batch = next(iterator_images)    # generating batch of images with iterator
       image = batch[0].astype('uint8')   # convert to unsigned integers
       plt.imshow(image)
    plt.show()
    return

# %%
# load the image
img = load_img('./cat.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)

# %% [markdown]
# ### width shift range
#
# ImageDataGenerator(width_shift_range=[-250,250])

# %%
# width shift range
datagen = ImageDataGenerator(width_shift_range=[-200,200])
# prepare iterator
it = datagen.flow(samples, batch_size=1)

plot_thumbnails(it) # plot samples to see changes in image

# %%
# height shift range
datagen = ImageDataGenerator(height_shift_range=[-200,200])

it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
# horizontal flip
datagen = ImageDataGenerator(horizontal_flip=True)
it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
# vertical flip
datagen = ImageDataGenerator(vertical_flip=True)
it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
# zooming image
datagen = ImageDataGenerator(zoom_range=[0.5,1.0])
it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
datagen = ImageDataGenerator(brightness_range=[0.2,1.0])
it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
datagen = ImageDataGenerator(rotation_range=90)
it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
# all together
datagen = ImageDataGenerator(zoom_range = 0.1,
                                  rotation_range = 20,
                                  width_shift_range = 0.2,
                                  height_shift_range = 0.2)
it = datagen.flow(samples, batch_size=1)
plot_thumbnails(it)

# %%
import session_info
session_info.show(html=False)
# Out:
# -----
# PIL                 11.0.0
# keras               3.6.0
# matplotlib          3.9.2
# numpy               1.26.4
# session_info        1.0.0
# -----
# IPython             8.28.0
# jupyter_client      8.6.3
# jupyter_core        5.7.2
# -----
# Python 3.12.3 (main, Nov  6 2024, 18:32:19) [GCC 13.2.0]
# Linux-5.15.167.4-microsoft-standard-WSL2-x86_64-with-glibc2.39
# -----
# Session information updated at 2025-01-16 12:49
